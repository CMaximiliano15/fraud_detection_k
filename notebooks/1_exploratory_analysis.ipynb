# %% [markdown]
# # 1. Exploratory Analisis

# %% [markdown]
# ## Setting Up: Installing useful libraries

# %%
#Importing necessary libraries

#Importing libraries for data manipulation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#For visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Setting Up: Upload and description
# I set up the creditcard database

# %%
df = pd.read_csv("G:\Mi unidad\Proyectos\Programacion\github-kaggle\creditcard_2023.csv")

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %% [markdown]
# Since it don't contain missing values, I continue with splitting the database into features and endogenous variable

# %% [markdown]
# ## Analyzing Feature Importance

# %%
#Visualizing the feature importances in a table format
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importance})
importance_df = importance_df.sort_values(by='Importance', ascending=False)
importance_df.reset_index(drop=True, inplace=True)
print(importance_df)
# Out:
#    Feature  Importance
# 0      V10    0.175023
# 1      V14    0.155112
# 2       V4    0.147704
# 3      V12    0.110335
# 4      V11    0.090299
# 5      V17    0.060710
# 6      V16    0.057337
# 7       V7    0.044503
# 8       V3    0.034230
# 9       V2    0.021477
# 10     V21    0.013567
# 11      V9    0.009541
# 12      V8    0.009080
# 13     V18    0.009066
# 14      V5    0.008082
# 15      V1    0.008007
# 16     V19    0.006388
# 17     V27    0.006059
# 18     V28    0.005227
# 19      V6    0.004594
# 20     V20    0.004017
# 21     V13    0.003591
# 22     V23    0.003201
# 23     V15    0.002995
# 24     V26    0.002658
# 25     V25    0.002633
# 26     V24    0.002607
# 27     V22    0.001952
# 28  Amount    0.000006

# %%
# Visualizing the feature importances in a bar chart
importance = rf.feature_importances_
feature_names = X_train.columns
indices = np.argsort(importance)[::-1]
plt.figure(figsize=(12, 8))
plt.title("Feature Importances", fontsize=20)
plt.bar(range(X_train.shape[1]), importance[indices], align='center')
plt.xticks(range(X_train.shape[1]), feature_names[indices], rotation=90)
plt.xlim([-1, X_train.shape[1]])
plt.show()

# %% [markdown]
# # Analyzing Multicollinearity

# %%
#To analyze multicollinearity, I'll calculate the correlation matrix
correlation_matrix=X_train.corr()
# Visualizing the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
plt.title('Correlation Matrix', fontsize=20)
plt.show()

# %%
# Evidently, there are some features that are highly correlated, such as
# V17 and V18, V17 and V16
# I will consider removing one of the features in each pair to reduce multicollinearity.
